# %% [markdown]
# <a href="https://colab.research.google.com/github/euzop/Barbell-Detection-YoloV8-Pose-Model/blob/main/Barbell_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="UjzEaGzyuPDWDmuYUxRo")
project = rf.workspace("techtitans-pcchf").project("barbell-detection-8phtm")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 11.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Barbell-Detection-6 in yolov8:: 100%|██████████| 5450/5450 [00:00<00:00, 5628.26it/s]

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# Run YOLO checks
# !yolo checks
# Out:
# Ultralytics 8.3.71 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.4/112.6 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.11.11
# Install             pip
# RAM                 12.67 GB
# Disk                33.4/112.6 GB
# CPU                 Intel Xeon 2.20GHz
# CPU count           2
# GPU                 Tesla T4, 15095MiB
# GPU count           1
# CUDA                12.4
#
# numpy               ✅ 1.26.4<=2.1.1,>=1.23.0
# matplotlib          ✅ 3.10.0>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 11.1.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.13.1>=1.4.1
# torch               ✅ 2.5.1+cu124>=1.8.0
# torch               ✅ 2.5.1+cu124!=2.4.0,>=1.8.0; sys_platform == "win32"
# torchvision         ✅ 0.20.1+cu124>=0.9.0
# tqdm                ✅ 4.67.1>=4.64.0
# ...

# %%
# !yolo task=pose mode=train model=yolov8s-pose.pt data={dataset.location}/data.yaml epochs=30 imgsz=640
# Out:
# Ultralytics 8.3.71 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
display(Image(filename='/content/runs/pose/train2/confusion_matrix.png', width=600))

# %%
display(Image(filename='/content/runs/pose/train2/results.png', width=600))

# %%
# !yolo task=pose mode=val model=/content/runs/pose/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.71 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8s-pose summary (fused): 187 layers, 11,412,453 parameters, 0 gradients, 29.4 GFLOPs
# val: Scanning /content/Barbell-Detection-6/valid/labels.cache... 112 images, 0 backgrounds, 0 corrupt: 100% 112/112 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% 7/7 [00:04<00:00,  1.67it/s]
#                    all        112        112          1      0.999      0.995      0.952          1      0.999      0.995      0.995
# Speed: 3.8ms preprocess, 10.7ms inference, 0.0ms loss, 4.1ms postprocess per image
# Results saved to runs/pose/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict3/*.jpg')[:3]:
	display(Image(filename=image_path, height=600))
	print("\n")

# %%
# !yolo task=pose mode=predict model=/content/runs/pose/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# WARNING ⚠️ 'source' argument is missing. Using default 'source=/usr/local/lib/python3.11/dist-packages/ultralytics/assets'.
# Ultralytics 8.3.71 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8s-pose summary (fused): 187 layers, 11,412,453 parameters, 0 gradients, 29.4 GFLOPs
#
# image 1/2 /usr/local/lib/python3.11/dist-packages/ultralytics/assets/bus.jpg: 640x480 (no detections), 74.9ms
# image 2/2 /usr/local/lib/python3.11/dist-packages/ultralytics/assets/zidane.jpg: 384x640 (no detections), 70.7ms
# Speed: 6.2ms preprocess, 72.8ms inference, 27.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/pose/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
